# %%
# !pip install ultralytics

# %%
import wandb
api_key = 'ccdf912083f622610063ad0ff31defb3972f6ee7'
wandb.login(key=api_key,relogin=True)

# %%
import os

from ultralytics import YOLO


model = YOLO('yolov8l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/kaggle/input/cattle-dataset-allinone2/data/data.yaml', epochs=50, imgsz=640,pretrained=True, cache=True)
